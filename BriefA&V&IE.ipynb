# %%
import numpy as np

import pandas as pd

import matplotlib as mpl

import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Livrables/BriefAV&IE/ventes-data.csv")

data
# Out:
#         Month           Product  Units Sold  Revenue
# 0     January        Smartphone        1000    50000
# 1     January            Laptop         500   100000
# 2     January            Tablet         300    45000
# 3     January          Smart TV         200    25000
# 4     January        Headphones         800    32000
# ..        ...               ...         ...      ...
# 583  December   Graphics Tablet         315    15750
# 584  December    Ink Cartridges         525    26250
# 585  December      Laptop Stand         210    10500
# 586  December  Portable Scanner         315    15750
# 587  December    Screen Cleaner         420     6300
#
# [588 rows x 4 columns]

# %%
data.head()
# Out:
#      Month     Product  Units Sold  Revenue
# 0  January  Smartphone        1000    50000
# 1  January      Laptop         500   100000
# 2  January      Tablet         300    45000
# 3  January    Smart TV         200    25000
# 4  January  Headphones         800    32000

# %%
#obtenir le nombre de lignes et de colonnes dans le DataFrame
data.shape
# Out:
# (588, 4)

# %%
#afficher les types de données de chaque colonne. 
data.dtypes
# Out:
# Month         object
# Product       object
# Units Sold     int64
# Revenue        int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       588 non-null    object
#  1   Product     588 non-null    object
#  2   Units Sold  588 non-null    int64
#  3   Revenue     588 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 18.5+ KB

# %%
#Vérifier les données manquantes :
#Utilisez la méthode isnull() pour vérifier les valeurs manquantes dans le DataFrame.
data.isnull()
# Out:
#      Month  Product  Units Sold  Revenue
# 0    False    False       False    False
# 1    False    False       False    False
# 2    False    False       False    False
# 3    False    False       False    False
# 4    False    False       False    False
# ..     ...      ...         ...      ...
# 583  False    False       False    False
# 584  False    False       False    False
# 585  False    False       False    False
# 586  False    False       False    False
# 587  False    False       False    False
#
# [588 rows x 4 columns]

# %%
#utiliser la méthode sum() pour compter le nombre de valeurs manquantes par colonne.
data.isnull().sum()
# Out:
# Month         0
# Product       0
# Units Sold    0
# Revenue       0
# dtype: int64

# %%
#Traiter les données manquantes

# Supprimer les lignes avec des valeurs manquantes
# df = df.dropna()

#supprimer les lignes du DataFrame où les valeurs d'une ou plusieurs colonnes spécifiques sont vides (valeurs manquantes),
#df = df.dropna(subset=['nom_de_la_colonne'])
#df = df.dropna(subset=['colonne1', 'colonne2', 'colonne3'])
#df = df.dropna(how='all') supprimera uniquement les lignes où toutes les valeurs sont manquantes dans ces lignes.


# Remplacer les valeurs manquantes par une valeur par défaut
# df = df.fillna(0)

# pour remplir les valeurs manquantes dans une colonne spécifique :
#df['nom_de_la_colonne'] = df['nom_de_la_colonne'].fillna(valeur_de_remplacement)

#remplir les valeurs manquantes dans plusieurs colonnes du DataFrame
#colonnes_a_remplir = ['colonne1', 'colonne2', 'colonne3']
#valeurs_de_remplacement = {'colonne1': valeur1, 'colonne2': valeur2, 'colonne3': valeur3}

#df[colonnes_a_remplir] = df[colonnes_a_remplir].fillna(valeurs_de_remplacement)

# %%
#pour obtenir des statistiques sommaires sur les variables numériques
data.describe()
# Out:
#         Units Sold        Revenue
# count   588.000000     588.000000
# mean    489.673469   31221.428571
# std     343.815948   27426.671012
# min     100.000000    3000.000000
# 25%     255.000000   12400.000000
# 50%     382.500000   24000.000000
# 75%     600.000000   41337.500000
# max    2100.000000  210000.000000

# %%
data
# Out:
#         Month           Product  Units Sold  Revenue
# 0     January        Smartphone        1000    50000
# 1     January            Laptop         500   100000
# 2     January            Tablet         300    45000
# 3     January          Smart TV         200    25000
# 4     January        Headphones         800    32000
# ..        ...               ...         ...      ...
# 583  December   Graphics Tablet         315    15750
# 584  December    Ink Cartridges         525    26250
# 585  December      Laptop Stand         210    10500
# 586  December  Portable Scanner         315    15750
# 587  December    Screen Cleaner         420     6300
#
# [588 rows x 4 columns]

# %%
ventes_totales_par_mois = data.groupby('Month')['Units Sold'].sum()
ventes_totales_par_mois
# Out:
# Month
# April        20124
# August       26316
# December     32508
# February     17028
# January      15480
# July         24768
# June         23220
# March        18576
# May          21672
# November     30960
# October      29412
# September    27864
# Name: Units Sold, dtype: int64

# %%
ventes_totales_par_mois_descendant = ventes_totales_par_mois.sort_values(ascending=False)
ventes_totales_par_mois_descendant
# Out:
# Month
# December     32508
# November     30960
# October      29412
# September    27864
# August       26316
# July         24768
# June         23220
# May          21672
# April        20124
# March        18576
# February     17028
# January      15480
# Name: Units Sold, dtype: int64

# %%
ventes_totales_par_mois_ascendant = ventes_totales_par_mois.sort_values(ascending=True)
ventes_totales_par_mois_ascendant
# Out:
# Month
# January      15480
# February     17028
# March        18576
# April        20124
# May          21672
# June         23220
# July         24768
# August       26316
# September    27864
# October      29412
# November     30960
# December     32508
# Name: Units Sold, dtype: int64

# %%
#groupby() de pandas pour regrouper les données par mois, puis appliquer la fonction sum() pour obtenir la somme des ventes ou revenue 

revenue_totales_par_mois = data.groupby('Month')['Revenue'].sum()
revenue_totales_par_mois
# Out:
# Month
# April        1283100
# August       1677900
# December     2072700
# February     1085700
# January       987000
# July         1579200
# June         1480500
# March        1184400
# May          1381800
# November     1974000
# October      1875300
# September    1776600
# Name: Revenue, dtype: int64

# %%
# afficher les revenues par mois par ordre de vente les plus elevées au moins élévées
revenue_totales_par_mois_descendant = revenue_totales_par_mois.sort_values(ascending=False)
revenue_totales_par_mois_descendant
# Out:
# Month
# December     2072700
# November     1974000
# October      1875300
# September    1776600
# August       1677900
# July         1579200
# June         1480500
# May          1381800
# April        1283100
# March        1184400
# February     1085700
# January       987000
# Name: Revenue, dtype: int64

# %%
# afficher revenue par mois par produit
revenue_totales_par_mois_produit = data.groupby(['Month','Product'])['Revenue'].sum()
revenue_totales_par_mois_produit
# Out:
# Month      Product
# April      Action Camera        19500
#            Battery Charger      13000
#            Bluetooth Adapter     7800
#            Car Charger          19500
#            Compact Camera       13000
#                                 ...
# September  Webcam               24300
#            Wi-Fi Extender        9000
#            Wireless Earbuds     36000
#            Wireless Mouse       10800
#            Wireless Speaker     64800
# Name: Revenue, Length: 588, dtype: int64

# %%
somme_produits_vendus_mois = data.groupby(['Month','Product'])['Units Sold'].sum()
somme_produits_vendus_mois
# Out:
# Month      Product
# April      Action Camera         390
#            Battery Charger       260
#            Bluetooth Adapter     260
#            Car Charger           650
#            Compact Camera        260
#                                 ...
# September  Webcam                540
#            Wi-Fi Extender        180
#            Wireless Earbuds      720
#            Wireless Mouse        180
#            Wireless Speaker     1080
# Name: Units Sold, Length: 588, dtype: int64

# %%
somme_produits_vendus = data.groupby(['Product'])['Units Sold'].sum()
somme_produits_vendus
# Out:
# Product
# Action Camera           5580
# Battery Charger         3720
# Bluetooth Adapter       3720
# Car Charger             9300
# Compact Camera          3720
# Drone                   2790
# External Hard Drive     2790
# Game Console            4650
# Gaming Mouse            7440
# Graphics Card           3348
# Graphics Tablet         2790
# HDMI Cable              5580
# Headphones             14880
# Ink Cartridges          4650
# Keyboard               10230
# Laptop                  9300
# Laptop Stand            1860
# Laser Printer           2790
# Mechanical Keyboard     4650
# Microphone              3720
# Monitor                13020
# Mouse                   8370
# Network Switch          2790
# Portable Scanner        2790
# Power Bank             14880
# Power Strip             5580
# Printer                 4650
# Processor               7440
# Projector               1860
# RAM                     5580
# Router                  6510
# ...

# %%
somme_produits_vendus = data.groupby(['Product'])['Units Sold'].sum()
somme_produits_vendus

# %%
somme_produits_vendus_max = somme_produits_vendus.idxmax()
somme_produits_vendus_max
# Out:
# 'Smartphone'

# %%
somme_produits_vendus_min = somme_produits_vendus.idxmin()
somme_produits_vendus_min
# Out:
# 'Laptop Stand'

# %%
# Identifiez les 5 produits les plus vendus chaque mois.
top5_Produits_plus_vendu_mois = somme_produits_vendus_mois.groupby('Month').nlargest(5).reset_index(level=0)
top5_Produits_plus_vendu_mois
# Out:
#                           Month  Units Sold
# Month     Product
# April     Smartphone      April        1300
#           Headphones      April        1040
#           Power Bank      April        1040
#           Monitor         April         910
#           USB Cable       April         910
# August    Smartphone     August        1700
#           Headphones     August        1360
#           Power Bank     August        1360
#           Monitor        August        1190
#           USB Cable      August        1190
# December  Smartphone   December        2100
#           Headphones   December        1680
#           Power Bank   December        1680
#           Monitor      December        1470
#           USB Cable    December        1470
# February  Smartphone   February        1100
#           Headphones   February         880
#           Power Bank   February         880
#           Monitor      February         770
#           USB Cable    February         770
# ...

# %%
# Identifiez les 5 produits les plus vendus chaque mois.
top5_Produits_plus_vendus_mois = somme_produits_vendus_mois.groupby('Month', group_keys=False).nlargest(5)
top5_Produits_plus_vendus_mois
# Out:
# Month      Product
# April      Smartphone    1300
#            Headphones    1040
#            Power Bank    1040
#            Monitor        910
#            USB Cable      910
# August     Smartphone    1700
#            Headphones    1360
#            Power Bank    1360
#            Monitor       1190
#            USB Cable     1190
# December   Smartphone    2100
#            Headphones    1680
#            Power Bank    1680
#            Monitor       1470
#            USB Cable     1470
# February   Smartphone    1100
#            Headphones     880
#            Power Bank     880
#            Monitor        770
#            USB Cable      770
# January    Smartphone    1000
#            Headphones     800
#            Power Bank     800
#            Monitor        700
#            USB Cable      700
# July       Smartphone    1600
#            Headphones    1280
#            Power Bank    1280
#            Monitor       1120
#            USB Cable     1120
# ...

# %%
# afficher les ventes par mois par ordre de vente les plus elevées au moins élévées
revenue_totales_par_mois_descendant = revenue_totales_par_mois.sort_values(ascending=False)
revenue_totales_par_mois_descendant
# Out:
# Month
# December     2072700
# November     1974000
# October      1875300
# September    1776600
# August       1677900
# July         1579200
# June         1480500
# May          1381800
# April        1283100
# March        1184400
# February     1085700
# January       987000
# Name: Revenue, dtype: int64

# %%
# afficher les ventes par mois par ordre de vente les plus elevées au moins élévées
revenue_totales_par_mois_ascendant = revenue_totales_par_mois.sort_values(ascending=True)
revenue_totales_par_mois_ascendant
# Out:
# Month
# January       987000
# February     1085700
# March        1184400
# April        1283100
# May          1381800
# June         1480500
# July         1579200
# August       1677900
# September    1776600
# October      1875300
# November     1974000
# December     2072700
# Name: Revenue, dtype: int64

# %%
top5_somme_produits_plus_vendus_annee = data.groupby(['Product'])['Units Sold'].sum().sort_values(ascending=False).head()
top5_somme_produits_plus_vendus_annee
# Out:
# Product
# Smartphone    18600
# Power Bank    14880
# Headphones    14880
# USB Cable     13020
# Monitor       13020
# Name: Units Sold, dtype: int64

# %%
top10_somme_produits_moins_vendus_annee = data.groupby(['Product'])['Units Sold'].sum().sort_values(ascending=False).tail(10)
top10_somme_produits_moins_vendus_annee
# Out:
# Product
# Laser Printer          2790
# Drone                  2790
# Portable Scanner       2790
# Graphics Tablet        2790
# External Hard Drive    2790
# Laptop Stand           1860
# Projector              1860
# VR Headset             1860
# Wi-Fi Extender         1860
# Wireless Mouse         1860
# Name: Units Sold, dtype: int64

# %%
#Trouvez le mois avec les ventes les plus elevées.
Mois_ventes_plus_elevées = ventes_totales_par_mois.idxmax()
Mois_ventes_plus_elevées
# Out:
# 'December'

# %%
#Trouvez le mois avec les ventes les plus basses.
Mois_ventes_plus_basses = ventes_totales_par_mois.idxmin()
Mois_ventes_plus_basses
# Out:
# 'January'

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

# %%
revenue_totales_par_mois_ascendant
# Out:
# Month
# January       987000
# February     1085700
# March        1184400
# April        1283100
# May          1381800
# June         1480500
# July         1579200
# August       1677900
# September    1776600
# October      1875300
# November     1974000
# December     2072700
# Name: Revenue, dtype: int64

# %%
#Graphique Linéaire 

# Création du graphique
# Définition de la taille du graphique:Crée une nouvelle figure de taille 15 pouces de largeur et 10 pouces de hauteur pour le graphique.
plt.figure(figsize=(15, 10))  
# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
plt.plot(revenue_totales_par_mois_ascendant.index, revenue_totales_par_mois_ascendant.values, color='b', marker='o')  


# Personnalisation du graphique
plt.title('Représentation des Revenues mensuelles pour chaque mois', fontsize=50)
plt.xlabel('Mois', fontsize=30)
plt.ylabel('Ventes', fontsize=30)
plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
plt.show()

# %%
#Graphique en secteur

plt.figure(figsize=(15, 10))  
plt.pie(revenue_totales_par_mois.values, labels=revenue_totales_par_mois.index, autopct='%1.1f%%')  


# Personnalisation du graphique
plt.title('Représentation des Ventes mensuelles', fontsize=50)
# Affichage du graphique
plt.show()

# %%
#Graphique en secteur

plt.figure(figsize=(15, 10))  
plt.pie(revenue_totales_par_mois_ascendant.values, labels=revenue_totales_par_mois_ascendant.index, autopct='%1.1f%%')  


# Personnalisation du graphique
plt.title('Représentation des Revenues mensuelles', fontsize=50)
# Affichage du graphique
plt.show()

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

#Graphique en nuage de points

plt.figure(figsize=(15, 10))  
# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
plt.scatter(revenue_totales_par_mois_ascendant.index, revenue_totales_par_mois_ascendant.values, color='r')  


# Personnalisation du graphique
plt.title('Représentation des Revenues mensuelles', fontsize=50)
plt.xlabel('Mois', fontsize=30)
plt.ylabel('Ventes', fontsize=30)
plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
plt.show()

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

#Graphique en histogramme: un histogramme peut être utilisé pour visualiser comment les ventes sont réparties sur différentes plages de valeurs.
#

#plt.figure(figsize=(15, 10))  
#plt.hist(revenue_totales_par_mois.values, bins=10)  


# Personnalisation du graphique
#plt.title('Représentation des Ventes mensuelles', fontsize=50)
#plt.xlabel('Ventes', fontsize=30)
#plt.ylabel('Frequence', fontsize=30)
#plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
#plt.show()

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

#Graphique en barre

plt.figure(figsize=(15, 10))  
# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
plt.bar(revenue_totales_par_mois.index, revenue_totales_par_mois.values)  


# Personnalisation du graphique
plt.title('Représentation des Ventes mensuelles', fontsize=50)
plt.xlabel('Mois', fontsize=30)
plt.ylabel('Ventes', fontsize=30)
plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
plt.show()

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

#Graphique en barre

plt.figure(figsize=(15, 10))  
# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
plt.bar(revenue_totales_par_mois_ascendant.index, revenue_totales_par_mois_ascendant.values)  


# Personnalisation du graphique
plt.title('Représentation des revenues mensuelles', fontsize=50)
plt.xlabel('Mois', fontsize=30)
plt.ylabel('Ventes', fontsize=30)
plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
plt.show()

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

#Graphique en 

plt.figure(figsize=(15, 10))  
# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
plt.barh(revenue_totales_par_mois_ascendant.index, revenue_totales_par_mois_ascendant.values)  


# Personnalisation du graphique
plt.title('Représentation des Revenues mensuelles', fontsize=50)
plt.xlabel('Ventes', fontsize=30)
plt.ylabel('Mois', fontsize=30)
plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
plt.show()

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

#Graphique en barre

plt.figure(figsize=(15, 10))  
# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
plt.bar(ventes_totales_par_mois_ascendant.index, ventes_totales_par_mois_ascendant.values)  


# Personnalisation du graphique
plt.title('Représentation des ventes mensuelles par mois', fontsize=50)
plt.xlabel('Mois', fontsize=30)
plt.ylabel('Ventes', fontsize=30)
plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
plt.show()

# %%
#revenue_totales_par_mois_produit = data.groupby(['Month','Product'])['Revenue'].sum()
revenue_totales_par_mois_produit
# Out:
# Month      Product
# April      Action Camera        19500
#            Battery Charger      13000
#            Bluetooth Adapter     7800
#            Car Charger          19500
#            Compact Camera       13000
#                                 ...
# September  Webcam               24300
#            Wi-Fi Extender        9000
#            Wireless Earbuds     36000
#            Wireless Mouse       10800
#            Wireless Speaker     64800
# Name: Revenue, Length: 588, dtype: int64

# %%
#somme_produits_vendus_mois = data.groupby(['Month','Product'])['Units Sold'].sum()
somme_produits_vendus_mois
# Out:
# Month      Product
# April      Action Camera         390
#            Battery Charger       260
#            Bluetooth Adapter     260
#            Car Charger           650
#            Compact Camera        260
#                                 ...
# September  Webcam                540
#            Wi-Fi Extender        180
#            Wireless Earbuds      720
#            Wireless Mouse        180
#            Wireless Speaker     1080
# Name: Units Sold, Length: 588, dtype: int64

# %%
#somme_produits_vendus = data.groupby(['Product'])['Units Sold'].sum()
somme_produits_vendus
# Out:
# Product
# Action Camera           5580
# Battery Charger         3720
# Bluetooth Adapter       3720
# Car Charger             9300
# Compact Camera          3720
# Drone                   2790
# External Hard Drive     2790
# Game Console            4650
# Gaming Mouse            7440
# Graphics Card           3348
# Graphics Tablet         2790
# HDMI Cable              5580
# Headphones             14880
# Ink Cartridges          4650
# Keyboard               10230
# Laptop                  9300
# Laptop Stand            1860
# Laser Printer           2790
# Mechanical Keyboard     4650
# Microphone              3720
# Monitor                13020
# Mouse                   8370
# Network Switch          2790
# Portable Scanner        2790
# Power Bank             14880
# Power Strip             5580
# Printer                 4650
# Processor               7440
# Projector               1860
# RAM                     5580
# Router                  6510
# ...

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

#Graphique en barre

plt.figure(figsize=(10, 6))  
# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
plt.bar(somme_produits_vendus.index, somme_produits_vendus.values, color='g')  


# Personnalisation du graphique
plt.title('Somme des ventes par produit', fontsize=50)
plt.xlabel('Produits', fontsize=30)
plt.ylabel('Ventes', fontsize=30)
plt.xticks(rotation=90)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
plt.show()

# %%
#  Utilisez Matplotlib pour créer des graphiques représentant les ventes mensuelles.

#Graphique en 

plt.figure(figsize=(15, 10))  
# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
plt.barh(somme_produits_vendus.index, somme_produits_vendus.values, color='b')  


# Personnalisation du graphique
plt.title('Somme des ventes par produit', fontsize=50)
plt.xlabel('Ventes', fontsize=30)
plt.ylabel('Produits', fontsize=30)
plt.xticks(rotation=90)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité

# Affichage du graphique
plt.show()

# %%
top5_somme_produits_plus_vendus_annee = data.groupby(['Product'])['Units Sold'].sum().sort_values(ascending=False).head()
top5_somme_produits_plus_vendus_annee
# Out:
# Product
# Smartphone    18600
# Power Bank    14880
# Headphones    14880
# USB Cable     13020
# Monitor       13020
# Name: Units Sold, dtype: int64

# %%
#Graphique en secteur

plt.figure(figsize=(15, 10))  
plt.pie(top5_somme_produits_plus_vendus_annee.values, labels=top5_somme_produits_plus_vendus_annee.index, autopct='%1.1f%%')  


# Personnalisation du graphique
plt.title("Top5 des Produits les plus vendus l'année", fontsize=50)
# Affichage du graphique
plt.show()

# %%
#top5_Produits_plus_vendus_mois = somme_produits_vendus_mois.groupby('Month', group_keys=False).nlargest(5)

top5_Produits_plus_vendus_mois
# Out:
# Month      Product
# April      Smartphone    1300
#            Headphones    1040
#            Power Bank    1040
#            Monitor        910
#            USB Cable      910
# August     Smartphone    1700
#            Headphones    1360
#            Power Bank    1360
#            Monitor       1190
#            USB Cable     1190
# December   Smartphone    2100
#            Headphones    1680
#            Power Bank    1680
#            Monitor       1470
#            USB Cable     1470
# February   Smartphone    1100
#            Headphones     880
#            Power Bank     880
#            Monitor        770
#            USB Cable      770
# January    Smartphone    1000
#            Headphones     800
#            Power Bank     800
#            Monitor        700
#            USB Cable      700
# July       Smartphone    1600
#            Headphones    1280
#            Power Bank    1280
#            Monitor       1120
#            USB Cable     1120
# ...

# %%
#Graphique Linéaire 

# Tracé de la courbe : Le paramètre marker='o' ajoute des points sur la courbe pour chaque mois.
top5_Produits_plus_vendus_mois.unstack().plot(kind="bar",stacked=False,figsize=(15, 10))  


plt.title("Top5 des produits plus vendus par mois aucours de l'année", fontsize=50)
plt.xlabel('Mois', fontsize=30)
plt.ylabel('Ventes', fontsize=30)
plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe des x pour une meilleure lisibilité
plt.legend(title="Products")

# Affichage du graphique
plt.show()

# %% [markdown]
# # Analysez les graphiques et tirez des conclusions sur les tendances de vente et les performances des produits.

# %% [markdown]
# ##### Analyse et conclusion 1 : les tendances générales des ventes au fil du temps
# D'après nos resultats, le mois de janvier est le mois ayant obtenu les ventes plus basses et mois de Decembre ventes plus hausse donc
# Nous remarquons donc une croissance progressive des ventes au fil du temps (mois) donc on peut conclure une tendance à la hausse au cours de l'année
#
# ##### Analyse et conclusion 2 : produits qui ont les ventes les plus élevées et plus basses
# Nous remarquons d'après notre Analyse que le Smarphone est le produit qui a obtenu le plus grand nombre de ventes qui est de 18600 et Laptop Stand le produit avec ventes plus basses qui est de 1860.
